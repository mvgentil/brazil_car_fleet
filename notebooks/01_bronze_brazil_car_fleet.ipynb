# %%
# =============================================================================
# Bronze · brazil_car_fleet
# Fonte: /Volumes/brazil_car_fleet/raw_data/fleet_raw/
# Ingestão do tipo Full Load
# =============================================================================

# %%
# %sql
USE CATALOG brazil_car_fleet;
USE SCHEMA bronze;

# %%
# %sql
DROP TABLE IF EXISTS brazil_car_fleet;

# %%
# %sql

CREATE TABLE brazil_car_fleet AS
SELECT * FROM read_files(
  '/Volumes/brazil_car_fleet/raw_data/fleet_raw/*.csv',
  header => true,
  format => 'csv',
  schema => 'nm_uf string, nm_municipio string, nm_combustivel string, qtd_veiculos integer, nm_file string'
);
